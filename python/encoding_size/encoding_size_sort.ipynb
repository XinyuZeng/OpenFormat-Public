# %%
import json
import os
import sys
import math
import datetime
import pathlib

dir_path = pathlib.Path(os.path.abspath('')).resolve()
print(dir_path)
HOME_DIR = str(dir_path).split('/OpenFormat')[0]

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

PROJ_SRC_DIR = f'{HOME_DIR}/OpenFormat'
sys.path.insert(1, f'{PROJ_SRC_DIR}')
from python.scripts.utils import *
# Out:
# /mnt/OpenFormat/python/encoding_size

# %%
num_rows = 1000 * 1000
num_cols = 20
sort_list = [
0.01,
        0.2,
        0.4,
        0.6,
        0.8,
        1
    ]
type_list = ['int', 'float', 'string']

# %%
# %%time
# generate csv files
os.chdir(f'{PROJ_SRC_DIR}/benchmark/generator_v2')
# !pwd
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        os.system(f'python3 gen_workloads.py \
            {t} {num_rows} {num_cols} {base_name} sort {s}')
        os.system(f'cp -r {base_name} {dir_path} && \
            rm -r {base_name}')
os.chdir(dir_path)
# !pwd
# Out:
# /mnt/OpenFormat/benchmark/generator_v2
# 🤔 INFO: too many collisions in int_unique_list, 25886 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 15772 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 317928 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 25886 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 15772 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 317928 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 254431 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 100961 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 54379 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 41981 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 408175 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 73779 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 43503 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 41974 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 38093 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 17565 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 733029 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 168 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 1 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 53882 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 11111 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 41262 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 56211 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 37817 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 7 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 7 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 3 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 131215 values just use (max_value + 1)!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in string_unique_list, generating time:33.37489724159241!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in string_unique_list, generating time:33.26393103599548!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in string_unique_list, generating time:36.30524468421936!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in string_unique_list, generating time:22.270744562149048!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in string_unique_list, generating time:62.120917320251465!
# 🤔 INFO: too many collisions in string_unique_list, generating time:45.07723951339722!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# /mnt/OpenFormat/python/encoding_size
# CPU times: user 90.2 ms, sys: 30.9 ms, total: 121 ms
# Wall time: 1h 15min 39s

# %%
pq_config = enumerate_config(f'{PROJ_SRC_DIR}/python/experiments/pq_encoding.json')
orc_config = enumerate_config(f'{PROJ_SRC_DIR}/python/experiments/orc_encoding.json')
pq_name_suffix = '_' + "_".join([str(i) for i in list(pq_config[0].values())]) + '.parquet'
orc_name_suffix = '_' + "_".join([str(i) for i in list(orc_config[0].values())]) + '.orc'
print(pq_config)
# Out:
# loading config from /mnt/OpenFormat/python/experiments/pq_encoding.json ...
# loading config from /mnt/OpenFormat/python/experiments/orc_encoding.json ...
# [{'compression': 'NONE', 'use_dictionary': True, 'dictionary_pagesize_limit': 2147483647, 'version': '2.6', 'data_page_version': '2.0'}]

# %%
# generate parquet and orc files
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        os.system(f'cp {dir_path}/{base_name}/gen_data/{base_name}.csv data_gen')
        os.system(f'python3 scripts/parquet_exp.py {base_name} pq_encoding -r=false -o=false')
        os.system(f'python3 scripts/orc_exp.py {base_name} orc_encoding -r=false -o=false')
        # orc_schema = open(f'encoding/{base_name}/gen_data/{base_name}_orc_schema.txt', 'r').read()
        # os.system(f'{HOME_DIR}/orc/build/tools/src/csv-import \"{orc_schema}\" \
        #         encoding/{base_name}/gen_data/{base_name}.csv {base_name}.orc')
        os.system(f'mv {base_name}{pq_name_suffix} {dir_path}/{base_name}.parquet')
        os.system(f'mv {base_name}{orc_name_suffix} {dir_path}/{base_name}.orc')
        # os.system(f'mv {base_name}.orc encoding/{base_name}.orc')
os.chdir(dir_path)
# Out:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.4691429138183594
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 1.0691592693328857
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.46938514709472656
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 1.0723896026611328
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.6380224227905273
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 1.1092731952667236
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.46153855323791504
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 1.03658127784729
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.44950222969055176
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.9808447360992432
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.4894554615020752
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.9487054347991943
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.41326332092285156
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.7666122913360596
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.34427928924560547
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6609025001525879
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.34035515785217285
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.61922287940979
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.3123042583465576
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.5411558151245117
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.32055234909057617
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.504462480545044
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.0971887111663818
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.619509220123291
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.069091796875
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6176936626434326
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.9131135940551758
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6095740795135498
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.0012519359588623
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6111958026885986
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.8775262832641602
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.610623836517334
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7200374603271484
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6091086864471436
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.719017505645752
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6155860424041748
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7179393768310547
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6088986396789551
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.4477822780609131
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.599034309387207
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.8815016746520996
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6206843852996826
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.5059552192687988
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 0.6210720539093018
# rm: cannot remove 'outputs/stats.json': No such file or directory
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 3.440876007080078
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 25.365508317947388
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 3.28057599067688
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 23.698657035827637
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 2.0699920654296875
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 11.787268161773682
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 2.1180670261383057
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 15.119995594024658
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.8617277145385742
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 10.559555292129517
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.8321480751037598
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 10.009485244750977
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.0873351097106934
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 3.907316207885742
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.1138756275177002
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 4.49587345123291
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.9839537143707275
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 3.2361538410186768
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.1005067825317383
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 4.82051420211792
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.9744148254394531
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 2.8000528812408447

# %%
# collect size
os.chdir(dir_path)
os.system('rm outputs/stats.json')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        output_stats = {}
        output_stats['type'] = t
        output_stats['feature'] = 'sort'
        output_stats['param'] = s
        output_stats['file'] = 'parquet'
        output_stats['size'] = os.path.getsize(f'{base_name}.parquet')
        parse_output(output_stats)
        output_stats['file'] = 'orc'
        output_stats['size'] = os.path.getsize(f'{base_name}.orc')
        parse_output(output_stats)
collect_results()
os.system('mv outputs/stats.csv ../outputs/{}_{}.csv'.format('encoding_size_sort', timestamp))
# Out:
# 0
